# %%
matrix = [[1,2,4,8],[10,11,12,13],[14,20,30,40]]
len(matrix[0][:])
matrix[1][len(matrix[1][:])-1]
# Out:
# 13

# %%
res = [1,2,4,8]

# %%
res[-1]
# Out:
# 8

# %%
res = []
res[-1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 res = []
# ----> 2 res[-1]
#
# IndexError: list index out of range

# %%
from collections import defaultdict

# %%
num = "42352338"
hmap = defaultdict(int)

for n in num:
    hmap[n] +=1

res = []
for key , values in hmap.items():
    if values >= 3:
        res.append(int(key))
        
res.sort()
n = res[-1]
print(str(n) * 3)
# Out:
# 333

# %%
# Python program to find whether a given number is a power of 4 or not.

import math


# Function to check if x is power of 4
def isPowerOfFour(n):
    if (n != 0 and n == pow(4, (math.log(n)/math.log(4)))):
        return True
    return False


test_no = 64
if(isPowerOfFour(test_no)):
    print(test_no, ' is a power of 4')
else:
    print(test_no, ' is not a power of 4')


# This code is contributed by lokesh (lokeshmvs21).
# Out:
# 64  is a power of 4

# %%
num = 99669
n = str(num)
res = ''
flag = 0
for i in n:
    print(i)
    if i == '6' and flag ==0:
        res += '9'
        flag = 1
    else:
        res += i
print(int(res))
# Out:
# 9
# 9
# 6
# 6
# 9
# 99969

# %%
n = 123

number = bin(n)[2:]

# %%
type(number)
# Out:
# str

# %%
n = 123
num = bin(n)[2:]
count = 0
for i in num:
    if i == '1':
        count +=1
print(count)
# Out:
# 0

# %%
res = 0
n = 123
while n:
    res += n%2
    n = n >> 1
    print(n)
print(res)
# Out:
# 61
# 30
# 15
# 7
# 3
# 1
# 0
# 6

# %%
ar = [2 , 4 , 5 , 7, 12, 33 , 22]
n = len(ar)
def sel_sort(arr , n):
    for i in range(n - 1):
        min_index = i
        for j in range(i+1 , n):
            if arr[j]<arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
sel_sort(ar , n)

# %%
print(ar)
# Out:
# [2, 4, 5, 7, 12, 22, 33]

# %%
def bub_sort(arr):
    n = len(arr)
    for i in range(n-1 , 0 , -1):
        for j in range(0 , i):
            if arr[j] > arr[j+1]:
                arr[j] , arr[j+1] = arr[j+1] , arr[j]

# %%
ar1 = [ 89 , 3, 56, 12, 34 , 23, 12]
bub_sort(ar1)
print(ar1)
# Out:
# [3, 12, 12, 23, 34, 56, 89]

# %%
def bub_sorto(arr):
    n = len(arr)
    for i in range(n):
        swap = False
        for j in range(0 , n-i-1):
            if arr[j] > arr[j+1]:
                arr[j] , arr[j+1] = arr[j+1] , arr[j]
                swap = True
        if not swap:
             break

# %%
ar1 = [ 89 , 3, 56, 12, 34 , 23, 12]
bub_sorto(ar1)
print(ar1)
# Out:
# [3, 12, 12, 23, 34, 56, 89]

# %%
def ins_sort(arr):
    n = len(arr)
    for i in range(n):
        j = i
        while (j >0 and arr[j-1]>arr[j]):
            arr[j] , arr[j-1] = arr[j-1] , arr[j]
            j -= 1

# %%
arr = [12, 11, 13, 5, 6]
ins_sort(arr)
print(arr)
# Out:
# [5, 6, 11, 12, 13]

# %%
nums1 = [1,2,3,0,0,0]
nums2 = [2,5,6]
m = 3
n = 3
j = 0
for i in range(m , len(nums1)):
    nums1[i] = nums2[j]
    j +=1

# %%
print(sorted(nums1))
# Out:
# [1, 2, 2, 3, 5, 6]

# %%
from itertools import accumulate
#this give prefix sum
# Cumulative sum (default behavior)
numbers = [1, 2, 3, 4, 5]
cumulative_sums = list(accumulate(numbers))
print(f"Cumulative sums: {cumulative_sums}")  # Output: [1, 3, 6, 10, 15]
# Out:
# Cumulative sums: [1, 3, 6, 10, 15]

# %%
points = [1, 4, 2, 9, 7, 8, 9, 3, 1]

x = points.count(9)
print(x)
res = list(accumulate(points)).count(0)
print(res)
# Out:
# 2
# 0

# %%
arr = [2,1,3 , 2,4,4]
start = min(arr)
end = max(arr)
i = 0
result = []
while i < len(arr):
    result.append(arr[i]-start)
    start +=1
    i +=1
print(result)
res = list(accumulate(result)).count(0)
print(res)
# Out:
# [1, -1, 0, -2, -1, -2]
# 2

# %%
#merge sort

# %%
def ms(arr , low , high):
    if low >= high:
        return
    mid = (low + high)//2
    ms(arr , low , mid )
    ms(arr , mid+1 , high)
    merge(arr , low , mid , high)
def merge(arr , low , mid , high):
    temp = []
    left = low
    right = mid+1
    while left <= mid and right <=high:
        if arr[left] <= arr[right]:
            temp.append(arr[left])
            left += 1
        else:
            temp.append(arr[right])
            right += 1
    while left <= mid:
        temp.append(arr[left])
        left += 1
    while right <= high:
        temp.append(arr[right])
        right += 1
    for i in range(low , high+1):
        arr[i] = temp[i-low]


points = [1 , 2 , 3 , 4, 5, 67, 200 , 100 , 0 , 23]

print(points)

ms(points , 0 , 9)

print(points)
# Out:
# [1, 2, 3, 4, 5, 67, 200, 100, 0, 23]
# [0, 1, 2, 3, 4, 5, 23, 67, 100, 200]
